# %%
#Manual Mode
import os, warnings
import sys
import glob
import numpy as np
import scipy.io as sio
import ruamel.yaml as yaml
yaml = yaml.YAML(typ='rt')
#%matplotlib widget # can be commented back in to make plots interactive
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import pickle

## import gui_configurations ##
from batch_process import gui_configurations as configurations


from run_suite2p import run_suite2p 

configurations.data_extension = 'nd2'
configurations.main_folder = r'D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02'
run_suite2p.export_image_files_to_suite2p_format(configurations.main_folder)
run_suite2p.main()
# Out:
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well012
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well012.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well012
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well013
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well013.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well013
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well014
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well014.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well014
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well015
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well015.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well015
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well016
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well016.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well016
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well017
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well017.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well017
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well018
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well018.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well018
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well019
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well019.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well019
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well020
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well020.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well020
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well021
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well021.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well021
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well022
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well022.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well022
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well023
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well023.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well023
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well024
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well024.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well024
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well001
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well001.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well001
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well002
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well002.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well002
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well003
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well003.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well003
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well004
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well004.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well004
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well005
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well005.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well005
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well006
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well006.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well006
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well007
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well007.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well007
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well008
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well008.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well008
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well009
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well009.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well009
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well010
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well010.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well010
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well011
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well011.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well011
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well012
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well012.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well012
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well013
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well013.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well013
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well014
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well014.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well014
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well015
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well015.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well015
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well016
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well016.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well016
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well017
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well017.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well017
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well018
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well018.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well018
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well019
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well019.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well019
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well020
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well020.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well020
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well021
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well021.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well021
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well022
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well022.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well022
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well023
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well023.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well023
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well024
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well024.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\brightfield\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_well024
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well012.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well013.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well014.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well015.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well016.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well017.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well018.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well019.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well020.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well021.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well022.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well023.csv
# Skipping non-nd2 file: baseline-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well024.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well001.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well002.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well003.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well004.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well005.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well006.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well007.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well008.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well009.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well010.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well011.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well012.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well013.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well014.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well015.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well016.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well017.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well018.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well019.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well020.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well021.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well022.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well023.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well024.csv
# Skipping non-nd2 file: t10-240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well001.csv
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well001
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well001.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well001
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well002
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well002.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well002
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well003
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well003.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well003
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well004
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well004.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well004
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well005
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well005.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well005
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well006
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well006.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well006
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well007
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well007.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well007
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well008
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well008.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well008
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well009
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well009.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well009
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well010
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well010.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well010
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well011
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well011.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well011
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well012
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well012.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well012
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well013
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well013.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well013
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well014
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well014.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well014
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well015
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well015.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well015
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well016
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well016.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well016
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well017
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well017.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well017
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well018
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well018.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well018
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well019
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well019.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well019
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well020
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well020.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well020
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well021
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well021.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well021
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well022
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well022.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well022
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well023
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well023.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well023
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well024
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well024.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t10_well024
# Skipping non-nd2 file: 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well001
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well001.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well001
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well002.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well002
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well003.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well003
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well004.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well004
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well005.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well005
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well006.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well006
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well007.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well007
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well008.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well008
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well009.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well009
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well010.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well010
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well011.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well011
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well012.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well012
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well013.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well013
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well014.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well014
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well015.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well015
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well016.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well016
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well017.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well017
# Processed and moved 240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well018.nd2 to D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well018
# Skipping non-nd2 file: new_suite2p
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well001.nd2
# time 16.96 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.77 sec.
# Binned movie denoised (for cell detection only) in 30.03 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 168 masks detected, median diameter = 14.16
# Detected 168 ROIs, 21.18 sec
# After removing overlaps, 168 ROIs remain
# ----------- Total 57.64 sec.
# ----------- EXTRACTION
# Masks created, 3.39 sec.
# Extracted fluorescence from 168 ROIs in 599 frames, 2.49 sec.
# ----------- Total 5.95 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 63.67 sec (can open in GUI).
# total = 80.87 sec.
# TOTAL RUNTIME 80.87 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well002.nd2
# time 11.23 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.70 sec.
# Binned movie denoised (for cell detection only) in 29.32 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 168 masks detected, median diameter = 11.59
# Detected 168 ROIs, 20.94 sec
# After removing overlaps, 168 ROIs remain
# ----------- Total 56.56 sec.
# ----------- EXTRACTION
# Masks created, 2.37 sec.
# Extracted fluorescence from 168 ROIs in 599 frames, 2.48 sec.
# ----------- Total 4.92 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 61.58 sec (can open in GUI).
# total = 72.97 sec.
# TOTAL RUNTIME 72.97 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well003.nd2
# time 12.54 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.67 sec.
# Binned movie denoised (for cell detection only) in 29.21 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 174 masks detected, median diameter = 12.91
# Detected 174 ROIs, 20.94 sec
# After removing overlaps, 174 ROIs remain
# ----------- Total 56.47 sec.
# ----------- EXTRACTION
# Masks created, 3.01 sec.
# Extracted fluorescence from 174 ROIs in 599 frames, 2.49 sec.
# ----------- Total 5.56 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.12 sec (can open in GUI).
# total = 74.88 sec.
# TOTAL RUNTIME 74.88 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well004.nd2
# time 11.95 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.70 sec.
# Binned movie denoised (for cell detection only) in 29.16 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 198 masks detected, median diameter = 12.05
# Detected 198 ROIs, 21.16 sec
# After removing overlaps, 198 ROIs remain
# ----------- Total 56.69 sec.
# ----------- EXTRACTION
# Masks created, 2.74 sec.
# Extracted fluorescence from 198 ROIs in 599 frames, 2.49 sec.
# ----------- Total 5.29 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.07 sec (can open in GUI).
# total = 74.17 sec.
# TOTAL RUNTIME 74.17 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well005.nd2
# time 9.48 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.73 sec.
# Binned movie denoised (for cell detection only) in 29.27 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 202 masks detected, median diameter = 13.63
# Detected 202 ROIs, 20.96 sec
# After removing overlaps, 202 ROIs remain
# ----------- Total 56.70 sec.
# ----------- EXTRACTION
# Masks created, 3.17 sec.
# Extracted fluorescence from 202 ROIs in 599 frames, 2.52 sec.
# ----------- Total 5.76 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.55 sec (can open in GUI).
# total = 72.18 sec.
# TOTAL RUNTIME 72.18 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well006.nd2
# time 9.68 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.27 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 176 masks detected, median diameter = 12.79
# Detected 176 ROIs, 20.78 sec
# After removing overlaps, 176 ROIs remain
# ----------- Total 56.43 sec.
# ----------- EXTRACTION
# Masks created, 2.93 sec.
# Extracted fluorescence from 176 ROIs in 599 frames, 2.51 sec.
# ----------- Total 5.50 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.02 sec (can open in GUI).
# total = 71.86 sec.
# TOTAL RUNTIME 71.87 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well007.nd2
# time 9.98 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.28 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 164 masks detected, median diameter = 13.28
# Detected 164 ROIs, 20.96 sec
# After removing overlaps, 164 ROIs remain
# ----------- Total 56.58 sec.
# ----------- EXTRACTION
# Masks created, 2.98 sec.
# Extracted fluorescence from 164 ROIs in 599 frames, 2.48 sec.
# ----------- Total 5.52 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.20 sec (can open in GUI).
# total = 72.36 sec.
# TOTAL RUNTIME 72.37 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well008.nd2
# time 9.72 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.28 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 180 masks detected, median diameter = 13.49
# Detected 180 ROIs, 21.12 sec
# After removing overlaps, 180 ROIs remain
# ----------- Total 56.79 sec.
# ----------- EXTRACTION
# Masks created, 3.06 sec.
# Extracted fluorescence from 180 ROIs in 599 frames, 2.49 sec.
# ----------- Total 5.61 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.48 sec (can open in GUI).
# total = 72.35 sec.
# TOTAL RUNTIME 72.35 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well009.nd2
# time 9.71 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.70 sec.
# Binned movie denoised (for cell detection only) in 29.32 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 201 masks detected, median diameter = 14.05
# Detected 201 ROIs, 21.05 sec
# After removing overlaps, 201 ROIs remain
# ----------- Total 56.82 sec.
# ----------- EXTRACTION
# Masks created, 3.75 sec.
# Extracted fluorescence from 201 ROIs in 599 frames, 2.51 sec.
# ----------- Total 6.33 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 63.25 sec (can open in GUI).
# total = 73.11 sec.
# TOTAL RUNTIME 73.11 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well010.nd2
# time 9.67 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.28 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 232 masks detected, median diameter = 13.04
# Detected 232 ROIs, 20.99 sec
# After removing overlaps, 232 ROIs remain
# ----------- Total 56.76 sec.
# ----------- EXTRACTION
# Masks created, 3.19 sec.
# Extracted fluorescence from 232 ROIs in 599 frames, 2.54 sec.
# ----------- Total 5.80 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.02 sec.
# Plane 0 processed in 62.68 sec (can open in GUI).
# total = 72.50 sec.
# TOTAL RUNTIME 72.50 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\baseline\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\baseline\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t0_well011.nd2
# time 9.90 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.31 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 214 masks detected, median diameter = 11.94
# Detected 214 ROIs, 20.89 sec
# After removing overlaps, 214 ROIs remain
# ----------- Total 56.67 sec.
# ----------- EXTRACTION
# ...
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well009\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well009.nd2
# time 10.46 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.70 sec.
# Binned movie denoised (for cell detection only) in 29.25 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 212 masks detected, median diameter = 13.89
# Detected 212 ROIs, 21.01 sec
# After removing overlaps, 212 ROIs remain
# ----------- Total 56.73 sec.
# ----------- EXTRACTION
# Masks created, 3.24 sec.
# Extracted fluorescence from 212 ROIs in 599 frames, 2.52 sec.
# ----------- Total 5.84 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.71 sec (can open in GUI).
# total = 73.31 sec.
# TOTAL RUNTIME 73.31 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well010'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well010\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well010.nd2
# time 10.66 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.32 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 282 masks detected, median diameter = 13.70
# Detected 282 ROIs, 20.95 sec
# After removing overlaps, 282 ROIs remain
# ----------- Total 56.93 sec.
# ----------- EXTRACTION
# Masks created, 3.37 sec.
# Extracted fluorescence from 282 ROIs in 599 frames, 2.57 sec.
# ----------- Total 6.00 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 63.09 sec (can open in GUI).
# total = 73.89 sec.
# TOTAL RUNTIME 73.89 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well011'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well011\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well011.nd2
# time 11.14 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.22 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 219 masks detected, median diameter = 12.91
# Detected 219 ROIs, 20.98 sec
# After removing overlaps, 219 ROIs remain
# ----------- Total 56.69 sec.
# ----------- EXTRACTION
# Masks created, 3.12 sec.
# Extracted fluorescence from 219 ROIs in 599 frames, 2.52 sec.
# ----------- Total 5.72 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.59 sec (can open in GUI).
# total = 73.89 sec.
# TOTAL RUNTIME 73.89 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well012'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well012\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well012.nd2
# time 11.54 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.23 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 194 masks detected, median diameter = 13.37
# Detected 194 ROIs, 20.97 sec
# After removing overlaps, 194 ROIs remain
# ----------- Total 56.59 sec.
# ----------- EXTRACTION
# Masks created, 3.02 sec.
# Extracted fluorescence from 194 ROIs in 599 frames, 2.53 sec.
# ----------- Total 5.61 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.35 sec (can open in GUI).
# total = 74.04 sec.
# TOTAL RUNTIME 74.04 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well013'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well013\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well013.nd2
# time 10.95 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.25 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 168 masks detected, median diameter = 14.03
# Detected 168 ROIs, 20.92 sec
# After removing overlaps, 168 ROIs remain
# ----------- Total 56.53 sec.
# ----------- EXTRACTION
# Masks created, 3.33 sec.
# Extracted fluorescence from 168 ROIs in 599 frames, 2.50 sec.
# ----------- Total 5.89 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.58 sec (can open in GUI).
# total = 73.68 sec.
# TOTAL RUNTIME 73.68 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well014'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well014\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well014.nd2
# time 10.19 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.30 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 243 masks detected, median diameter = 12.46
# Detected 243 ROIs, 21.03 sec
# After removing overlaps, 243 ROIs remain
# ----------- Total 56.87 sec.
# ----------- EXTRACTION
# Masks created, 3.02 sec.
# Extracted fluorescence from 243 ROIs in 599 frames, 2.54 sec.
# ----------- Total 5.63 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.63 sec (can open in GUI).
# total = 72.96 sec.
# TOTAL RUNTIME 72.96 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well015'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well015\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well015.nd2
# time 10.42 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.69 sec.
# Binned movie denoised (for cell detection only) in 29.20 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 192 masks detected, median diameter = 14.18
# Detected 192 ROIs, 20.97 sec
# After removing overlaps, 192 ROIs remain
# ----------- Total 56.57 sec.
# ----------- EXTRACTION
# Masks created, 3.52 sec.
# Extracted fluorescence from 192 ROIs in 599 frames, 2.51 sec.
# ----------- Total 6.09 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.81 sec (can open in GUI).
# total = 73.39 sec.
# TOTAL RUNTIME 73.39 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well016'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well016\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well016.nd2
# time 11.78 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.70 sec.
# Binned movie denoised (for cell detection only) in 29.23 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 209 masks detected, median diameter = 13.06
# Detected 209 ROIs, 21.14 sec
# After removing overlaps, 209 ROIs remain
# ----------- Total 56.79 sec.
# ----------- EXTRACTION
# Masks created, 3.24 sec.
# Extracted fluorescence from 209 ROIs in 599 frames, 2.52 sec.
# ----------- Total 5.82 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.76 sec (can open in GUI).
# total = 74.68 sec.
# TOTAL RUNTIME 74.68 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well017'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well017\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well017.nd2
# time 10.51 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.72 sec.
# Binned movie denoised (for cell detection only) in 29.28 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 209 masks detected, median diameter = 12.77
# Detected 209 ROIs, 21.02 sec
# After removing overlaps, 209 ROIs remain
# ----------- Total 56.77 sec.
# ----------- EXTRACTION
# Masks created, 3.10 sec.
# Extracted fluorescence from 209 ROIs in 599 frames, 2.51 sec.
# ----------- Total 5.67 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.01 sec.
# Plane 0 processed in 62.65 sec (can open in GUI).
# total = 73.29 sec.
# TOTAL RUNTIME 73.29 sec
# {'h5py': [], 'h5py_key': 'data', 'look_one_level_down': False, 'data_path': ['D:\\users\\JC\\pipeline\\cysteine toxicity\\002-HCO3\\Cysteine toxicity 24.09.06\\plate02\\t10\\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well018'], 'subfolders': [], 'fast_disk': 'C:\\BIN'}
# nd2
# ** Found 1 nd2 files - converting to binary **
# Nikon files:
# D:\users\JC\pipeline\cysteine toxicity\002-HCO3\Cysteine toxicity 24.09.06\plate02\t10\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well018\240906_wtRt_C2208_DIV15_100k_bc_plate02_10x_t60_well018.nd2
# time 11.24 sec. Wrote 599 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, ops['do_registration']=0
# binary path: C:\BIN\suite2p\plane0\data.bin
# NOTE: applying default C:\Users\zeiss\.suite2p\classifiers\classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 02
# Binned movie of size [299,1022,1024] created in 3.71 sec.
# Binned movie denoised (for cell detection only) in 29.30 sec.
# >>>> CELLPOSE finding masks in mean_img
# !NOTE! diameter set to 12.00 for cell detection with cellpose
# >>>> 233 masks detected, median diameter = 11.73
# Detected 233 ROIs, 21.01 sec
# After removing overlaps, 233 ROIs remain
# ----------- Total 56.84 sec.
# ----------- EXTRACTION
# Masks created, 2.72 sec.
# Extracted fluorescence from 233 ROIs in 599 frames, 2.52 sec.
# ----------- Total 5.30 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.02 sec.
# Plane 0 processed in 62.31 sec (can open in GUI).
# total = 73.69 sec.
# TOTAL RUNTIME 73.69 sec

# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import tqdm
from pathlib import Path
from PIL import Image
# !pip install nd2reader
from nd2reader import ND2Reader #only if converting to tiff
import shutil
# sys.path.insert(0, 'D:/users/JC/suite2p-0.14.0')
from suite2p import run_s2p

import configurations
#potential issue here in that configurations would need to 
#be accessed in both virtual environments if we define a directory here

BASE_DIR = configurations.main_folder

def getFilesWithExt(top_dir, files_ext):
    matches = []
    for root, dirnames, filenames in os.walk(str(top_dir)):
        for _dir in dirnames:
            matches += getFilesWithExt(_dir, files_ext)
        for filename in filenames:
            full_path = os.path.join(root, filename)
            if full_path.endswith(files_ext):
                matches.append(Path(os.path.join(root, filename)))
    return matches

def convertND2toTiff(fp_pathlib):
    
    print("Attempting to convert:", str(fp_pathlib))
    save_fp = tiffPathFromND2(fp_pathlib)
    save_dir = save_fp.parent
    print(f"Saving to: {save_fp} in dir: {save_dir}")
    save_dir.mkdir(parents=False, exist_ok = True)
    with ND2Reader(str(fp_pathlib)) as images:
        images_li=[]
        images.iter_axes='t'
        for idx in range(len(images)):
            images_li.append(Image.fromarray(np.array(images[idx])))
        images_li[0].save(save_fp, save_all=True, append_images=images_li[1:])
        print("Done converting")
        
def tiffPathFromND2(_file):
    return Path(f"{_file.parent}/{_file.stem}/{_file.stem}.tif")

def iterConvert():
    tiff_files = getFilesWithExt(BASE_DIR, ".tif")
    files_to_convert = [_file for _file in getFilesWithExt(BASE_DIR, ".nd2")
                       if tiffPathFromND2(_file) not in tiff_files]
    print("Files to convert:", files_to_convert)
    print("Total number of files to convert:", len(files_to_convert))
    for fp in tqdm.tqdm(files_to_convert):
        print(f"Processing {fp.name}.tif")
        convertND2toTiff(fp)

#iterConvert()



def export_image_files_to_suite2p_format(parent_directory, file_ending= configurations.data_extension):
    """Export each image file (with variable file extension) into its own folder for suite2p processing, for all directories within a given parent directory."""
    
    if not os.path.exists(parent_directory):
        print(f"Provided path does not exist: {parent_directory}")
        return
    
    # Process each directory within the parent directory
    for dir_name in os.listdir(parent_directory):
        dir_path = os.path.join(parent_directory, dir_name)
        if not os.path.isdir(dir_path):
            print(f"Skipping non-directory path: {dir_path}")
            continue

        # Processing each file within the directory
        for file in os.listdir(dir_path):
            if file.endswith(file_ending):
                name, _ = os.path.splitext(file)
                folder_path = os.path.join(dir_path, name)
                os.makedirs(folder_path, exist_ok=True)

                source = os.path.join(dir_path, file)
                destination = os.path.join(folder_path, file)

                try:
                    shutil.copy(source, destination)
                    os.remove(source)
                    print(f"Processed and moved {file} to {folder_path}")
                except Exception as e:
                    print(f"Failed to process {file} due to {e}")
            else:
                print(f"Skipping non-{file_ending} file: {file}")
#Loading in suite2p settings to begin processing



def get_all_image_folders_in_path(path):
    """
    Find all folders within a given path that contain exactly one .nd2 file in their deepest subfolder.
    
    Nested Function:
    - check_for_single_image_file_in_folder: Checks if a given directory contains exactly one .nd2 file.
    """

    def check_for_single_image_file_in_folder(current_path, file_ending = configurations.data_extension):
        """
        Check if the specified path contains exactly one .nd2 file.
        """
        tiff_files = [file for file in os.listdir(current_path) if file.endswith(file_ending)]
        return len(tiff_files) == 1

    found_image_folders = []
    for current_path, directories, files in os.walk(path):
        # Check if current directory is a "deepest" directory (no subdirectories)
        if check_for_single_image_file_in_folder(current_path):
            found_image_folders.append(current_path)

    return found_image_folders

# Example Usage:
# image_folders = get_all_image_folders_in_path('/path/to/search')
# print(image_folders)

def process_files_with_suite2p(image_list):
        """
        Processes a list of image paths using the run_s2p function, applying specified configurations.

        Args:
        image_list (list of str): List of file paths to the images to be processed.
        """
        for image_path in image_list:
            try:
                 fast_disk_path = r'C:\BIN'
                 if not os.path.exists(fast_disk_path):
                      os.makedirs(fast_disk_path)
                 db = {
                    'h5py': [], # a single h5 file path
                    'h5py_key': 'data',
                    'look_one_level_down': False, # whether to look in ALL subfolders when searching for images
                    'data_path': [image_path], # a list of folders with images 
                                                        # (or folder of folders with images if look_one_level_down is True, or subfolders is not empty)
                                                        
                    'subfolders': [], # choose subfolders of 'data_path' to look in (optional)
                    'fast_disk': fast_disk_path, # string which specifies where the binary file will be stored (should be an SSD)
                 }
            
                 opsEnd = run_s2p(ops=configurations.ops, db=db)
            except (ValueError, AssertionError, IndexError) as e:
                 print(f"Error processing {image_path}: {e}")

def main():
    main_folder = configurations.main_folder
    data_extension = configurations.data_extension
    export_image_files_to_suite2p_format(main_folder, file_ending = '.' + data_extension)
    image_folders = get_all_image_folders_in_path(main_folder)
    process_files_with_suite2p(image_folders)


# if __name__ == "__main__":
#     main()


"""To Run:
activate suite2p
import run_suite2p 
if __name__ == "__main__":
    run_suite2p.main()
    """
# Out:
# 'To Run:\nactivate suite2p\nimport run_suite2p \nif __name__ == "__main__":\n    run_suite2p.main()\n    '
